# %% [markdown]
# <a href="https://colab.research.google.com/github/sasan-osmannezhad/test/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
## Generate Random data with Numpy

# %%
observation = 1000
x = np.random.uniform(-10,10,size = (observation,1))
z = np.random.uniform(-10,10,size = (observation,1))

inputs = np.column_stack((x,z))

# %%
print(inputs.shape)

print(x.ndim)

print(y.ndim)

print(x.shape)

print(z.shape)

print(type(inputs))
print(type(z))
# Out:
# (1000, 2)
# 2
# 2
# (1000, 1)
# (1000, 1)
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %% [markdown]
# Supervised learning algoritms need targets ,
#
# our target can be:
#
# target = 2x +5 z + 20 + noise

# %%
noise = np.random.uniform(-.01 , .01 , size= (observation,1))

print(noise.shape)

print(noise.ndim)

target = 2*x - 5*z + 20 + noise
# Out:
# (1000, 1)
# 2

# %% [markdown]
# Let's plot our made up data with numpy

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

# Data for a three-dimensional line
zline = z
xline = y
yline = target
ax.plot3D(xline, yline, zline, 'gray')

ax.set_xlabel("x")

ax.set_ylabel("target")

ax.set_zlabel("z")

ax.view_init(azim=200)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print(target.ndim)
print(x.ndim)
print(y.ndim)
print(target.shape)
print(x.shape)
print(target.shape)
print(inputs.shape)
print(inputs.ndim)
# Out:
# 2
# 2
# 2
# (1000, 1)
# (1000, 1)
# (1000, 1)
# (1000, 2)
# 2

# %% [markdown]
# now , set the first varibles

# %% [markdown]
# ## the first weights and biases is better set by us and do not forget that the shabe of wieght should be acording of our inputs

# %%
weight  = np.random.uniform(-.01,.02, size=(2,1))

biase  = np.random.uniform(.001,.002, size=1)

print(weight)
print(biase)
# Out:
# [[ 0.01293906]
#  [-0.00992756]]
# [0.0015918]

# %% [markdown]
# seting laerning rate

# %%
learning_rate = .03

# %%
print(inputs.shape)
delta.shape
# Out:
# (1000, 2)
# (1000, 1)

# %% [markdown]
# trianing data

# %%
epoch = 140

for i in range (epoch):
  output = np.dot(inputs,weight) + biase #y = xw +b
  delta = output - target
  loss = np.sum(delta**2)/2 / observation # LOSS = ∑1/2*(y - y)**2 , divid on observation due to make scaled
  print (loss)

  delta_scaled = delta/observation

  weight = weight - learning_rate* np.dot(inputs.T, delta_scaled) # ∑ δx

  biase = biase - learning_rate * np.sum(delta_scaled)

# %%
print (weight,biase)
#target = 2*x - 5*z + 20 + noise
# Out:
# [[ 1.99999322]
#  [-5.00002162]] [20.00021573]

# %%
plt.plot(output,target)

plt.xlabel("output")
plt.ylabel("target")
plt.show()
